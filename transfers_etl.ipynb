# %%
# !pip install pandas
# !pip install datatable
# !pip install numpy

# %%
import pandas as pd
import numpy as np
from google.colab import drive
from io import StringIO # python3; python2: BytesIO
import boto3
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
csv = pd.read_csv("/content/drive/MyDrive/SPL/saudi-pro-league-transfers.csv")

# %%
csv.tail(2)
# Out:
#         club_name      player_name   age            position  \
# 8058   Khaleej FC     Pedro Amaral  25.0           Left-Back
# 8059  Al-Fateh SC  Christian Cueva  32.0  Attacking Midfield
#
#      club_involved_name                      fee transfer_movement  \
# 8058       Without Club                        -               out
# 8059       Alianza Lima  End of loanDec 31, 2023                in
#
#      transfer_period  fee_cleaned                league_name  year     season  \
# 8058          Summer          NaN  Saudi Professional League  2023  2023/2024
# 8059          Winter          NaN  Saudi Professional League  2023  2023/2024
#
#            country club_involved_country
# 8058  Saudi Arabia          Without Club
# 8059  Saudi Arabia                  Peru

# %%
df = csv[["club_name", "country","player_name", "age", "position", "club_involved_name", "club_involved_country","transfer_movement","transfer_period","year"]]

# %%
df
# Out:
#          club_name       country         player_name   age  \
# 0     Al-Hilal SFC  Saudi Arabia         Khaled Aziz  18.0
# 1     Al-Hilal SFC  Saudi Arabia       Sami Al-Jaber  27.0
# 2     Al-Hilal SFC  Saudi Arabia  Fahad Al-Ghesheyan  26.0
# 3     Al-Hilal SFC  Saudi Arabia   Saleh Al-Salloumi  37.0
# 4     Al-Hilal SFC  Saudi Arabia       Elijah Litana  29.0
# ...            ...           ...                 ...   ...
# 8055    Khaleej FC  Saudi Arabia   Mohammed Al-Sahli  32.0
# 8056    Khaleej FC  Saudi Arabia    Hisham Al-Dubais  21.0
# 8057    Khaleej FC  Saudi Arabia   Izuchukwu Anthony  25.0
# 8058    Khaleej FC  Saudi Arabia        Pedro Amaral  25.0
# 8059   Al-Fateh SC  Saudi Arabia     Christian Cueva  32.0
#
#                 position club_involved_name club_involved_country  \
# 0     Defensive Midfield            Unknown               Unknown
# 1         Centre-Forward             Wolves               England
# ...

# %%
df.loc[5:6] = df.loc[:, ["club_involved_name", "club_involved_country"]].replace("Unknown", None)
df.loc[5:6] = df.loc[:, ["club_involved_name", "club_involved_country"]].replace("Without Club", "Free Agent")

# %%
df
# Out:
#          club_name       country         player_name   age  \
# 0     Al-Hilal SFC  Saudi Arabia         Khaled Aziz  18.0
# 1     Al-Hilal SFC  Saudi Arabia       Sami Al-Jaber  27.0
# 2     Al-Hilal SFC  Saudi Arabia  Fahad Al-Ghesheyan  26.0
# 3     Al-Hilal SFC  Saudi Arabia   Saleh Al-Salloumi  37.0
# 4     Al-Hilal SFC  Saudi Arabia       Elijah Litana  29.0
# ...            ...           ...                 ...   ...
# 8055    Khaleej FC  Saudi Arabia   Mohammed Al-Sahli  32.0
# 8056    Khaleej FC  Saudi Arabia    Hisham Al-Dubais  21.0
# 8057    Khaleej FC  Saudi Arabia   Izuchukwu Anthony  25.0
# 8058    Khaleej FC  Saudi Arabia        Pedro Amaral  25.0
# 8059   Al-Fateh SC  Saudi Arabia     Christian Cueva  32.0
#
#                 position club_involved_name club_involved_country  \
# 0     Defensive Midfield            Unknown               Unknown
# 1         Centre-Forward             Wolves               England
# ...

# %%
df.iloc[:, ['age', 'year']] = df.iloc[:, ['age', 'year']].fillna(0)
df.iloc[:, ['age', 'year']] = df.iloc[:, ['age', 'year']].astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ead37e7bcd21> in <cell line: 1>()
# ----> 1 df.iloc[:, ['age', 'year']] = df.iloc[:, ['age', 'year']].fillna(0)
#       2 df.iloc[:, ['age', 'year']] = df.iloc[:, ['age', 'year']].astype(np.int64)
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#          club_name       country         player_name  age            position  \
# 0     Al-Hilal SFC  Saudi Arabia         Khaled Aziz   18  Defensive Midfield
# 1     Al-Hilal SFC  Saudi Arabia       Sami Al-Jaber   27      Centre-Forward
# 2     Al-Hilal SFC  Saudi Arabia  Fahad Al-Ghesheyan   26        Right Winger
# 3     Al-Hilal SFC  Saudi Arabia   Saleh Al-Salloumi   37          Goalkeeper
# 4     Al-Hilal SFC  Saudi Arabia       Elijah Litana   29         Centre-Back
# ...            ...           ...                 ...  ...                 ...
# 8055    Khaleej FC  Saudi Arabia   Mohammed Al-Sahli   32         Left Winger
# 8056    Khaleej FC  Saudi Arabia    Hisham Al-Dubais   21            Midfield
# 8057    Khaleej FC  Saudi Arabia   Izuchukwu Anthony   25         Centre-Back
# 8058    Khaleej FC  Saudi Arabia        Pedro Amaral   25           Left-Back
# 8059   Al-Fateh SC  Saudi Arabia     Christian Cueva   32  Attacking Midfield
#
# ...
